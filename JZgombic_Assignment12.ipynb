# %% [markdown]
# # IS 362 - Assignment 12
#
# ## Johnny Zgombic
#
#
# ### Project Tasks
#
# ##### The task is to choose one of the New York Times APIs, construct an interface in Python to read in the JSON data, and transform it into a pandas DataFrame.

# %% [markdown]
# **The first step in our program is to import the necessary modules in order to work with our data.**

# %%
import json
import pandas as pd
import urllib.request as request
from pandas.io.json import json_normalize as normal

# %% [markdown]
# **The next step in our program is to create an account on the NY Times developer website so that we may get an API Key. Once registered, we receive our key and proceed with the following steps.**

# %%
APIKey = 'ZauSvWOie8CPRxfMjyT4AQAK4KWKt2TU'
url = 'https://api.nytimes.com/svc/movies/v2/reviews/search.json?'
address = url+'&api-key='+APIKey

# %% [markdown]
# **We will now take our data and load the JSON Data into a new variable.**

# %%
data = str(request.urlopen(address).read(), 'utf-8')
load_data = json.loads(data)

# %% [markdown]
# **We now take our JSON data and normalize it and once again assign it to another variable and show our output.**

# %%
output = normal(load_data['results'])
output
# Out:
#                  byline  critics_pick         date_updated  \
# 0        Manohla Dargis             1  2019-11-27 17:44:22
# 1            A.O. Scott             1  2019-11-27 17:44:22
# 2            A.O. Scott             0  2019-11-27 17:44:21
# 3            A.O. Scott             1  2019-11-27 17:44:20
# 4   Jeannette Catsoulis             1  2019-11-27 17:44:18
# 5        Manohla Dargis             0  2019-11-27 17:44:21
# 6         Bilal Qureshi             0  2019-11-21 19:10:02
# 7        Manohla Dargis             0  2019-11-27 17:44:20
# 8            A.O. Scott             0  2019-11-27 17:44:19
# 9           Glenn Kenny             0  2019-11-21 12:04:03
# 10       Ben Kenigsberg             0  2019-11-27 17:44:19
# 11  Jeannette Catsoulis             0  2019-11-27 17:44:18
# 12          Glenn Kenny             0  2019-11-27 17:44:18
# 13       Manohla Dargis             1  2019-11-27 17:44:16
# 14           A.O. Scott             1  2019-11-27 17:44:16
# ...
